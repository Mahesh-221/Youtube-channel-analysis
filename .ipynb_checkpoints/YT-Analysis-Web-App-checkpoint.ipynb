# %%
import pandas as  pd
import numpy as np
from IPython.display import JSON
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

import isodate
import DateTime as dt

#Google API
from googleapiclient.discovery import build

# %%
#NLP Libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud

# %%
api_key = 'AIzaSyCLieiVplSrw-2EQr_9Pisv4uuNdAduXxU'

# %%
channel_id = 'UCqW8jxh4tH1Z1sWPbkGWL4g'

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey = api_key)

# %%
#Function to get channel stats
def get_channel_stats(youtube, channel_id):

    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id= channel_id
    )
    response = request.execute()
    
    # loop through items
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        
        all_data.append(data)
    return pd.DataFrame(all_data)



#Function to get video ids from the channels.
def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

#Function to get Video data
def get_video_details(youtube, video_ids):
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    return pd.DataFrame(all_video_info)

# %%
flights = sns.load_dataset("flights")
flights2 = flights.pivot("month", "year", "passengers")
#ax = sns.heatmap(flights)
flights2.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
channel_stats = get_channel_stats(youtube, channel_id)

# %%
channel_stats
# Out:
#           channelName subscribers     views totalVideos  \
# 0  Akshat Shrivastava     1070000  92214503         462
#
#                  playlistId
# 0  UUqW8jxh4tH1Z1sWPbkGWL4g

# %%
playlist_id = channel_stats['playlistId'][0]

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 463

# %%
video_df = get_video_details(youtube, video_ids)
video_df.head()
# Out:
#       video_id        channelTitle  \
# 0  VX4FC7w6S1g  Akshat Shrivastava
# 1  4Dg9h7_yjww  Akshat Shrivastava
# 2  sduYG7IT-mw  Akshat Shrivastava
# 3  RMMSiS_ltZc  Akshat Shrivastava
# 4  _tdKZzvtcOA  Akshat Shrivastava
#
#                                                title  \
# 0                            Stocks that I am buying
# 1        MAJOR DIP: Why (and HOW) am I still buying?
# 2  Explainer: Inflation is KILLING the world, BUT...
# 3  SAVE MONEY and wait for the stock market botto...
# 4  How you can make Rs. 50 Lakhs from these 3 typ...
#
#                                          description  \
# 0  ►You can check out ET Money for individual sto...
# 1  ►Health insurance premiums are likely to rise ...
# 2  ►You can check out The Undercover Economist on...
# 3  ► Have trouble filing your taxes? Do check out...
# 4  ►To learn more about blockchain, cryptos and N...
#
#                                                 tags           publishedAt  \
# ...

# %% [markdown]
# Data Preprocessing

# %%
video_df.isnull().sum()
# Out:
# video_id            0
# channelTitle        0
# title               0
# description         0
# tags                8
# publishedAt         0
# viewCount           0
# likeCount           0
# favouriteCount    463
# commentCount        0
# duration            0
# definition          0
# caption             0
# dtype: int64

# %%
video_df.drop('favouriteCount', axis=1, inplace=True) #Droping the fav_count column

# %%
df = video_df.copy() #Creating a copy of data

# %%
df.info() #To know the data types of all the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   video_id      463 non-null    object
#  1   channelTitle  463 non-null    object
#  2   title         463 non-null    object
#  3   description   463 non-null    object
#  4   tags          455 non-null    object
#  5   publishedAt   463 non-null    object
#  6   viewCount     463 non-null    object
#  7   likeCount     463 non-null    object
#  8   commentCount  463 non-null    object
#  9   duration      463 non-null    object
#  10  definition    463 non-null    object
#  11  caption       463 non-null    object
# dtypes: object(12)
# memory usage: 43.5+ KB

# %%
#Converting columns (String) values into numeric
df['viewCount'] = df['viewCount'].astype(int)
df['likeCount'] = df['likeCount'].astype(int)
df['commentCount'] = df['commentCount'].astype(int)

# %%
df['caption'].value_counts() #consider using caption for analysis only if its true for 25% or more of his videos
# Out:
# true     347
# false    116
# Name: caption, dtype: int64

# %%
df['definition'].value_counts()
# Out:
# hd    462
# sd      1
# Name: definition, dtype: int64

# %%
df[df['viewCount'] == 0]
# Out:
#         video_id        channelTitle                           title  \
# 441  BJpqRjwJDxw  Akshat Shrivastava  Akshat Shrivastava Live Stream
#
#     description  tags           publishedAt  viewCount  likeCount  \
# 441              None  2021-05-15T17:10:56Z          0          0
#
#      commentCount duration definition caption
# 441             0      P0D         sd   false

# %%
zero_views = df.index[df['viewCount'] == 0].tolist()

# %%
df.drop(df.index[zero_views], inplace=True)

# %%
df[df['viewCount'] == 0]
# Out:
# Empty DataFrame
# Columns: [video_id, channelTitle, title, description, tags, publishedAt, viewCount, likeCount, commentCount, duration, definition, caption]
# Index: []

# %%
#df.drop(df.index[df['viewCount'] == 0],axis=0, inplace=True) #if any videos has 0 view,like,comment count < 5%, then drop them

# %%
 #converting duration into seconds
df['duration_secs'] = df['duration'].apply(lambda x: isodate.parse_duration(x))
df['duration_secs'] = df['duration_secs'].astype('timedelta64[s]')

# %%
df[['duration', 'duration_secs']]
# Out:
#      duration  duration_secs
# 0    PT19M46S         1186.0
# 1     PT22M2S         1322.0
# 2    PT17M45S         1065.0
# 3    PT14M16S          856.0
# 4    PT16M25S          985.0
# ..        ...            ...
# 458  PT12M30S          750.0
# 459   PT8M43S          523.0
# 460   PT9M12S          552.0
# 461   PT2M50S          170.0
# 462  PT47M44S         2864.0
#
# [462 rows x 2 columns]

# %%
df.drop('duration', axis=1, inplace=True) #Droping duration column

# %%
#Creating new columns from date and time
df['published_date'] = df['publishedAt'].str.split('T').str[0]   
df['published_time'] =  df['publishedAt'].str.split('T').str[1].str.split('Z').str[0]

# %%
#Converting String formatted date into date format
df['published_date'] = pd.to_datetime(df['published_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 462 entries, 0 to 462
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        462 non-null    object
#  1   channelTitle    462 non-null    object
#  2   title           462 non-null    object
#  3   description     462 non-null    object
#  4   tags            455 non-null    object
#  5   publishedAt     462 non-null    object
#  6   viewCount       462 non-null    int32
#  7   likeCount       462 non-null    int32
#  8   commentCount    462 non-null    int32
#  9   definition      462 non-null    object
#  10  caption         462 non-null    object
#  11  duration_secs   462 non-null    float64
#  12  published_date  462 non-null    datetime64[ns]
#  13  published_time  462 non-null    object
# dtypes: datetime64[ns](1), float64(1), int32(3), object(9)
# memory usage: 48.7+ KB

# %%
#Deriving weekday from date column
df['day_of_week'] = df['published_date'].dt.weekday

# %%
#Mapping the Weekday number to weekdays
df['day_of_week'] = df['day_of_week'].map({0:'Mon', 1:'Tue', 2:'Wed', 3:'Thu', 4:'Fri', 5:'Sat', 6:'Sun'})

# %%
#New column with tag count 
df['tags_count'] = df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
df.head()
# Out:
#       video_id        channelTitle  \
# 0  VX4FC7w6S1g  Akshat Shrivastava
# 1  4Dg9h7_yjww  Akshat Shrivastava
# 2  sduYG7IT-mw  Akshat Shrivastava
# 3  RMMSiS_ltZc  Akshat Shrivastava
# 4  _tdKZzvtcOA  Akshat Shrivastava
#
#                                                title  \
# 0                            Stocks that I am buying
# 1        MAJOR DIP: Why (and HOW) am I still buying?
# 2  Explainer: Inflation is KILLING the world, BUT...
# 3  SAVE MONEY and wait for the stock market botto...
# 4  How you can make Rs. 50 Lakhs from these 3 typ...
#
#                                          description  \
# 0  ►You can check out ET Money for individual sto...
# 1  ►Health insurance premiums are likely to rise ...
# 2  ►You can check out The Undercover Economist on...
# 3  ► Have trouble filing your taxes? Do check out...
# 4  ►To learn more about blockchain, cryptos and N...
#
#                                                 tags           publishedAt  \
# ...

# %%
oldest = min(df['published_date'])

# %%
oldest
# Out:
# Timestamp('2020-08-24 00:00:00')

# %%
max(df['published_date'])
# Out:
# Timestamp('2022-06-21 00:00:00')

# %%
df2 = df.iloc[:,[6,10,14,15]]

# %%
df2.head()
# Out:
#    viewCount caption day_of_week  tags_count
# 0     171098    true         Mon          23
# 1     125258    true         Sat          23
# 2     282069    true         Fri          27
# 3     122193    true         Wed          23
# 4     193871   false         Tue          24

# %%
#df3 = df2.pivot('day_of_week', 'caption', 'tags_count')
#df4 = df2.pivot('day_of_week', 'caption', 'viewCount')

# %%
sns.heatmap(df2.corr())
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='day_of_week', y='viewCount', data=df2)
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='viewCount'>

# %%
flights = sns.load_dataset("flights")
flights2 = flights.pivot("month", "year", "passengers")
#ax = sns.heatmap(flights)
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights2.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %% [markdown]
# ### Data Analysis

# %%
df.groupby('caption').size().reset_index()

# %%
df_caption = df[df['caption'] == 'true']
df_no_caption = df[df['caption'] == 'false']

Avg_vews = round(df['viewCount'].mean())
Avg_likes = round(df['likeCount'].mean())
Avg_comments = round(df['commentCount'].mean())

Avg_views_with_caption = round(df_caption['viewCount'].mean())
Avg_likes_with_caption = round(df_caption['likeCount'].mean())
Avg_comments_with_caption = round(df_caption['commentCount'].mean())

Avg_views_without_caption = round(df_no_caption['viewCount'].mean())
Avg_likes_without_caption = round(df_no_caption['likeCount'].mean())
Avg_comments_without_caption = round(df_no_caption['commentCount'].mean()

# %%
#Should be shown in dashboard

if len(df[df['caption'] == 'true']) > (len(df[df['caption'] == 'false']) + len(df[df['caption'] == 'true']))*0.25:
    
    df_caption = df[df['caption'] == 'true']
    df_no_caption = df[df['caption'] == 'false']
    
    print('Avg views of all videos :' + str(round(df['viewCount'].mean())))
    print('Avg likes of all videos :' + str(round(df['likeCount'].mean())))
    print('Avg comments from all videos :' + str(round(df['commentCount'].mean())))
    
    print('Avg views of videos with caption :' + str(round(df_caption['viewCount'].mean())))
    print('Avg likes of videos with caption :' + str(round(df_caption['likeCount'].mean())))
    print('Avg comments from videos with caption :' + str(round(df_caption['commentCount'].mean())))
    
    print('Avg views of videos with no caption :' + str(round(df_no_caption['viewCount'].mean())))
    print('Avg likes of videos with no caption :' + str(round(df_no_caption['likeCount'].mean())))
    print('Avg comments from videos with no caption :' + str(round(df_no_caption['commentCount'].mean())))

else:
    print('Didnt consider caption in analysis')

# %%
#should be shown in dashboard - stating the conclusion 

if len(df[df['caption'] == 'true']) > (len(df[df['caption'] == 'false']) + len(df[df['caption'] == 'true']))*0.9:
   
    if Avg_views_with_caption > Avg_views_without_caption:
    print('Avg views with caption is ' + 
          str(round((Avg_views_with_caption - Avg_views_without_caption)/Avg_views_without_caption*100)) + '%'
               + ' Greater than Avg views without caption')
    else: 
        print('Avg views with caption is' + 
              str(round((Avg_views_without_caption - Avg_views_with_caption)/Avg_views_with_caption*100)) + '%'
                   + ' Less than Avg views without caption')

    if Avg_likes_with_caption > Avg_likes_without_caption:
        print('Avg likes with caption is ' + 
              str(round((Avg_likes_with_caption - Avg_likes_without_caption)/Avg_likes_without_caption*100)) + '%'
                   + ' Greater than Avg likes without caption')
    else: 
        print('Avg likes with caption is' + 
              str(round((Avg_likes_without_caption - Avg_likes_with_caption)/Avg_likes_with_caption*100)) + '%'
                   + ' Less than Avg likes without caption')

    if Avg_comments_with_caption > Avg_comments_without_caption:
        print('Avg comments with caption is ' + 
              str(round((Avg_comments_with_caption - Avg_comments_without_caption)/Avg_comments_without_caption*100)) + '%'
                   + ' Greater than Avg comments without caption')
    else: 
        print('Avg comments with caption is' + 
              str(round((Avg_comments_without_caption - Avg_comments_with_caption)/Avg_comments_with_caption*100)) + '%'
                   + ' Less than Avg comments without caption')
    
    
else: 
    print('Didnt consider caption for analysis')

# %%
slider_1 = 66
slider_2 = 147
sdate = str(df.iloc[slider_1,12]).replace('.0','')

# %%
sdate.replace('00:00:00','').strip()
# Out:
# '2022-04-10'

# %%
df.head()
# Out:
#       video_id        channelTitle  \
# 0  4Dg9h7_yjww  Akshat Shrivastava
# 1  sduYG7IT-mw  Akshat Shrivastava
# 2  RMMSiS_ltZc  Akshat Shrivastava
# 3  _tdKZzvtcOA  Akshat Shrivastava
# 4  WznnmWum1oQ  Akshat Shrivastava
#
#                                                title  \
# 0        MAJOR DIP: Why (and HOW) am I still buying?
# 1  Explainer: Inflation is KILLING the world, BUT...
# 2  SAVE MONEY and wait for the stock market botto...
# 3  How you can make Rs. 50 Lakhs from these 3 typ...
# 4   Explainer: Why a RECESSION in 2022 A GOOD THING!
#
#                                          description  \
# 0  ►Health insurance premiums are likely to rise ...
# 1  ►You can check out The Undercover Economist on...
# 2  ► Have trouble filing your taxes? Do check out...
# 3  ►To learn more about blockchain, cryptos and N...
# 4  ►You can check out Changing World Order by Ray...
#
#                                                 tags           publishedAt  \
# ...

# %%
num_of_words = len(df['title'][4].split())

# %%
num_of_words
# Out:
# 10

# %%
df['title'][:62]
# Out:
# 'Explainer: Inflation is KILLING the world, BUT not Japan, why?'

# %%
df['title'][8]
# Out:
# 'How to retire EARLY in India? | What is F.I.R.E ? | Retirement Planning | Akshat Shrivastava'

# %%
#df['title'].str.contains(pat = '|')

# %%
df['short_title'] = df['title'][:62]

# %%
y = df['title'].str.split('|').str[0]

# %%
y[4]
# Out:
# 'MARKET CRASH '

# %%
def sentiment_category(sentiment):
    label = ''
    if(sentiment>0):
        label = 'positive'
    elif(sentiment == 0):
        label = 'neutral'
    else:
        label = 'negative'
    return(label)

df['sentiment_category'] = df['sentiment'].apply(sentiment_category)

# %%
d_char = "|"   #short title creation
q_char = "?"

for i in df['title']:
    if len(i.split()) > 10:
        if d_char in i:
            df['st2'] = df['title'].str.split('|').str[0]
        elif q_char in i:
            df['st2'] = df['title'].str.split('?').str[0]
        else:
            df['st2'] = df['title'][:62]
    else:
        df['st2'] = df['title']

# %%
df['st2'][4]
# Out:
# 'MARKET CRASH | How and when to BUY the DIP?'

# %%
len(df)
# Out:
# 460

# %%
df['title'][2][:60]
# Out:
# 'How you can make Rs. 50 Lakhs from these 3 types of BUSINESS'

# %%
#Highest view count
ax = sns.barplot(x='title', y='viewCount', data=df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/100000) + 'L'))

# %%
#lowest view count

ay = sns.barplot(x='title', y='viewCount', data=df.sort_values('viewCount', ascending=True)[0:9])
plot = ay.set_xticklabels(ay.get_xticklabels(), rotation=90)
ay.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %%
fig, ax = plt.subplots(1,2)
sns.set(rc = {'figure.figsize':(20,20)})
ay = sns.barplot(x='title', y='likeCount', data=df.sort_values('likeCount', ascending=True)[0:9], ax=ax[0])
plot = ay.set_xticklabels(ay.get_xticklabels(), rotation=90)
ay = sns.barplot(x='title', y='likeCount', data=df.sort_values('likeCount', ascending=False)[0:9], ax=ax[1])
plot = ay.set_xticklabels(ay.get_xticklabels(), rotation=90)

# %%
Top_views = df.sort_values('viewCount', ascending=False)[0:9]
Bottom_likes = df.sort_values('likeCount', ascending=True)[0:9]
Bottom_views = df.sort_values('viewCount', ascending=True)[0:9]
Top_likes = df.sort_values('likeCount', ascending=False)[0:9]

# %%
df5 = pd.merge(Top_views, Top_likes, on="title", how='inner')
df6 = pd.merge(Bottom_views, Bottom_likes, on="title", how='inner')

# %%
round(len(df5)/len(Top_views)*100)
# Out:
# 44

# %%
round(len(df6)/len(Bottom_views)*100)
# Out:
# 78

# %%
# View Distribution across videos
fig, ax = plt.subplots(1,2)
#sns.set(rc = {'figure.figsize':(10,10)})
sns.violinplot(df['channelTitle'], df['viewCount'], ax=ax[0])
df.boxplot(by ='channelTitle', column =['viewCount'], grid = False, ax=ax[1])
# Out:
# C:\Users\91784\anaconda3\envs\vir_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'viewCount'}, xlabel='channelTitle'>

# %%
sns.pairplot(df, kind="scatter") #scatter plot of all the columns with numeric values

# %%
#views vs likes scatterplot
fig, ax = plt.subplots(1,2)
sns.set(rc = {'figure.figsize':(10,15)})
sns.scatterplot(data = df, x='commentCount', y='viewCount', ax=ax[0])
sns.scatterplot(data = df, x='likeCount', y='viewCount', ax=ax[1])
# Out:
# <AxesSubplot:xlabel='likeCount', ylabel='viewCount'>

# %%
#Duration vs views 
sns.scatterplot(data = df, x='duration_secs', y='viewCount')
# Out:
# <AxesSubplot:xlabel='duration_secs', ylabel='viewCount'>

# %%
#video duration
sns.histplot(data = df, x='duration_secs', bins=30)
# Out:
# <AxesSubplot:xlabel='duration_secs', ylabel='Count'>

# %%
#Wordcloud of Title
stop_words = set(stopwords.words('english'))
df['title_no_stopwords'] = df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %%
#Wordcloud of Tags
stop_words = set(stopwords.words('english'))
df['tags_no_stopwords'] = df['tags'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in df['tags_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %%
#upload schedule
sns.countplot(x='day_of_week', data = df)
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='count'>

# %%
df.head()
# Out:
#       video_id        channelTitle  \
# 0  4Dg9h7_yjww  Akshat Shrivastava
# 1  sduYG7IT-mw  Akshat Shrivastava
# 2  RMMSiS_ltZc  Akshat Shrivastava
# 3  _tdKZzvtcOA  Akshat Shrivastava
# 4  WznnmWum1oQ  Akshat Shrivastava
#
#                                                title  \
# 0        MAJOR DIP: Why (and HOW) am I still buying?
# 1  Explainer: Inflation is KILLING the world, BUT...
# 2  SAVE MONEY and wait for the stock market botto...
# 3  How you can make Rs. 50 Lakhs from these 3 typ...
# 4   Explainer: Why a RECESSION in 2022 A GOOD THING!
#
#                                          description  \
# 0  ►Health insurance premiums are likely to rise ...
# 1  ►You can check out The Undercover Economist on...
# 2  ► Have trouble filing your taxes? Do check out...
# 3  ►To learn more about blockchain, cryptos and N...
# 4  ►You can check out Changing World Order by Ray...
#
#                                                 tags           publishedAt  \
# ...

# %%
#Finding out Published hr from Time and converting into int
df['published_in_hr'] = df['published_time'].str.split(':').str[0].astype(int)

# %%
#Turning the UTC Hr into IST
df['publishedhr_in_IST'] = df['published_in_hr']+5

# %%
#Countplot of Published_Hr
sns.countplot(x='publishedhr_in_IST', data = df)
# Out:
# <AxesSubplot:xlabel='publishedhr_in_IST', ylabel='count'>

# %%
df['publishedhr_in_IST'].value_counts()
# Out:
# 20    341
# 17     23
# 21     20
# 19     20
# 18     19
# 13      8
# 16      7
# 22      6
# 15      5
# 14      3
# 12      3
# 10      3
# 11      2
# 9       1
# Name: publishedhr_in_IST, dtype: int64

# %%
# % of videos uploaded between 6pm to 9pm
(333+23+20+20+19)/453*100
# Out:
# 91.61147902869757

# %%
# % of videos uploaded between 8pm to 9pm
(333)/453*100
# Out:
# 73.50993377483444

# %%
#spliting the data into two, with and without captions
df_no_caption = df[df['caption'] != 'true']
df_caption = df[df['caption'] != 'false']

# %%
# View Distribution across videos with captions
sns.violinplot(df_caption['channelTitle'], df['viewCount'])
# Out:
# C:\Users\91784\anaconda3\envs\vir_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %%
# View Distribution across videos with no captions
sns.violinplot(df_no_caption['channelTitle'], df['viewCount'])

# %%
sns.pairplot(df_caption, kind="scatter") #scatterplot of all columns in data with captions

# %%
sns.pairplot(df_no_caption, kind="scatter") #scatterplot of all columns in data without captions

# %%
df_caption['viewCount'].mean()  #Avg of views in videos with captions

# %%
df_no_caption['viewCount'].mean()  #Avg of views in videos without captions

# %%
df_caption['likeCount'].mean()  #Avg of likes in videos with captions

# %%
df_no_caption['likeCount'].mean() #Avg of likes in videos without captions

# %%
df_caption['commentCount'].mean() #Avg of comments in videos with captions

# %%
df_no_caption['commentCount'].mean() #Avg of comments in videos without captions

# %% [markdown]
# Its clear that videos with captions get more views and likes compared to videos with no captions.

# %%
df['viewCount'].mean()

# %%
df['likeCount'].mean()

# %%
df['commentCount'].mean()

# %%
df.head()
# Out:
#       video_id        channelTitle  \
# 0  4Dg9h7_yjww  Akshat Shrivastava
# 1  sduYG7IT-mw  Akshat Shrivastava
# 2  RMMSiS_ltZc  Akshat Shrivastava
# 3  _tdKZzvtcOA  Akshat Shrivastava
# 4  WznnmWum1oQ  Akshat Shrivastava
#
#                                                title  \
# 0        MAJOR DIP: Why (and HOW) am I still buying?
# 1  Explainer: Inflation is KILLING the world, BUT...
# 2  SAVE MONEY and wait for the stock market botto...
# 3  How you can make Rs. 50 Lakhs from these 3 typ...
# 4   Explainer: Why a RECESSION in 2022 A GOOD THING!
#
#                                          description  \
# 0  ►Health insurance premiums are likely to rise ...
# 1  ►You can check out The Undercover Economist on...
# 2  ► Have trouble filing your taxes? Do check out...
# 3  ►To learn more about blockchain, cryptos and N...
# 4  ►You can check out Changing World Order by Ray...
#
#                                                 tags           publishedAt  \
# ...
